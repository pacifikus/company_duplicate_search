# %%
import pandas as pd

# %%
PREPROC_DATA_PATH = '/work/data/train_prepcroc.csv'

# %%
df = pd.read_csv(PREPROC_DATA_PATH)

# %%
df.columns
# Out:
# Index(['pair_id', 'name_1', 'name_2', 'is_duplicate', 'fuzz_ratio',
#        'fuzz_part_ratio', 'fuzz_set_ratio', 'fuzz_sort_ratio',
#        'name_1_simhash', 'name_2_simhash', 'name_1_minhash', 'name_2_minhash'],
#       dtype='object')

# %%
df[['name_1_minhash', 'name_2_minhash']].to_csv('train_minhash.csv', index=False)

# %%
df[['name_1_simhash', 'name_2_simhash']].to_csv('train_simhash.csv', index=False)

# %%
df[['pair_id', 'name_1', 'name_2', 'is_duplicate', 'fuzz_ratio',
       'fuzz_part_ratio', 'fuzz_set_ratio', 'fuzz_sort_ratio']].to_csv(PREPROC_DATA_PATH, index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b045afd9-a76f-4856-9836-14ff20b55163' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
