# %%
from deep_translator import (GoogleTranslator,
                             PonsTranslator,
                             LingueeTranslator,
                             MyMemoryTranslator,
                             YandexTranslator,
                            #  DeepL,
                            #  QCRI,
                             single_detection,
                             batch_detection)

# %%
transl = GoogleTranslator()
langs_dict = transl.get_supported_languages(as_dict=True) 
langs_dict
# Out:
# {'afrikaans': 'af',
#  'albanian': 'sq',
#  'amharic': 'am',
#  'arabic': 'ar',
#  'armenian': 'hy',
#  'azerbaijani': 'az',
#  'basque': 'eu',
#  'belarusian': 'be',
#  'bengali': 'bn',
#  'bosnian': 'bs',
#  'bulgarian': 'bg',
#  'catalan': 'ca',
#  'cebuano': 'ceb',
#  'chichewa': 'ny',
#  'chinese (simplified)': 'zh-CN',
#  'chinese (traditional)': 'zh-TW',
#  'corsican': 'co',
#  'croatian': 'hr',
#  'czech': 'cs',
#  'danish': 'da',
#  'dutch': 'nl',
#  'english': 'en',
#  'esperanto': 'eo',
#  'estonian': 'et',
#  'filipino': 'tl',
#  'finnish': 'fi',
#  'french': 'fr',
#  'frisian': 'fy',
#  'galician': 'gl',
#  'georgian': 'ka',
#  'german': 'de',
#  'greek': 'el',
#  'gujarati': 'gu',
#  'haitian creole': 'ht',
#  'hausa': 'ha',
#  'hawaiian': 'haw',
#  'hebrew': 'iw',
#  'hindi': 'hi',
#  'hmong': 'hmn',
#  'hungarian': 'hu',
#  'icelandic': 'is',
#  'igbo': 'ig',
#  'indonesian': 'id',
#  'irish': 'ga',
#  'italian': 'it',
#  'japanese': 'ja',
#  'javanese': 'jw',
#  'kannada': 'kn',
#  'kazakh': 'kk',
#  'khmer': 'km',
#  'kinyarwanda': 'rw',
#  'korean': 'ko',
#  'kurdish': 'ku',
#  'kyrgyz': 'ky',
#  'lao': 'lo',
#  'latin': 'la',
#  'latvian': 'lv',
#  'lithuanian': 'lt',
#  'luxembourgish': 'lb',
#  'macedonian': 'mk',
#  'malagasy': 'mg',
#  'malay': 'ms',
#  'malayalam': 'ml',
#  'maltese': 'mt',
#  'maori': 'mi',
#  'marathi': 'mr',
#  'mongolian': 'mn',
#  'myanmar': 'my',
#  'nepali': 'ne',
#  'norwegian': 'no',
#  'odia': 'or',
#  'pashto': 'ps',
#  'persian': 'fa',
#  'polish': 'pl',
#  'portuguese': 'pt',
#  'punjabi': 'pa',
#  'romanian': 'ro',
#  'russian': 'ru',
#  'samoan': 'sm',
#  'scots gaelic': 'gd',
#  'serbian': 'sr',
#  'sesotho': 'st',
#  'shona': 'sn',
#  'sindhi': 'sd',
#  'sinhala': 'si',
#  'slovak': 'sk',
#  'slovenian': 'sl',
#  'somali': 'so',
#  'spanish': 'es',
#  'sundanese': 'su',
#  'swahili': 'sw',
#  'swedish': 'sv',
#  'tajik': 'tg',
#  'tamil': 'ta',
#  'tatar': 'tt',
#  'telugu': 'te',
#  'thai': 'th',
#  'turkish': 'tr',
#  'turkmen': 'tk',
#  'ukrainian': 'uk',
#  'urdu': 'ur',
#  'uyghur': 'ug',
#  'uzbek': 'uz',
#  'vietnamese': 'vi',
#  'welsh': 'cy',
#  'xhosa': 'xh',
#  'yiddish': 'yi',
#  'yoruba': 'yo',
#  'zulu': 'zu'}

# %%
# lang = single_detection('bonjour la vie', api_key='****')# 1000 request per day fo free plan
# print(lang) # output: fr

# %%
from langdetect import detect
detect("War doesn't show who's right, just who's left.")
# Out:
# 'en'

# %%
detect("Ein, zwei, drei, vier")
# Out:
# 'de'

# %%
import pandas as pd

# %%
RAW_DATA_PATH = '/work/data/train_prepcroc.csv'
PREPROC_DATA_PATH = '/work/data/train_prepcroc.csv'

# %%
df = pd.read_csv(RAW_DATA_PATH)

# %%
df['name_1_lang'] = df.apply(lambda x: detect(x.name_1), axis=1)

# %%
df['name_2_lang'] = df.apply(lambda x: detect(x.name_2), axis=1)

# %%
df.to_csv(PREPROC_DATA_PATH, index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b045afd9-a76f-4856-9836-14ff20b55163' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
